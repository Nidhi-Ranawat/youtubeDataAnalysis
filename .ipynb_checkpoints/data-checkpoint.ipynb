# %%
import seaborn as sns
import pandas as pd
import googleapiclient.discovery
import matplotlib.pyplot as plt

# %% [markdown]
# ### DEFINING channel IDs and creating a youtube object to interact with the YouTube API.

# %%
api_key = 'AIzaSyDXKI6EHquvwYO-YUOkPfCMx1YXi4FABF8';

channel_ids = [
               'UCt-k6JwNWHMXDBGm9IYHdsg',#JBalvin  
               'UC0WP5P-ufpRfjbNrmOWwLBQ',#Weeknd
               'UCPNxhDvTcytIdvwXWAm43cA',#selena
               'UCzpl23pGTHVYqvKsgY0A-_w',#doja
               'UCgJMQU7JOIoP-YnrhH_P-bA',#WDW 
               'UCtG5oKSlksz-QmD_2uI4WBw',#DPR
              ]
youtube = googleapiclient.discovery.build('youtube', 'v3', developerKey = api_key);
type(youtube)
# Out:
# googleapiclient.discovery.Resource

# %% [markdown]
# ### Getting playlists details using channel ids

# %%
def getPlaylists(youtube, channel_ids):
    playlistResponse = []

    for channel_id in channel_ids:
        request = youtube.playlists().list(
            part = 'snippet, contentDetails',
            channelId = channel_id,
            maxResults = 50
            )
        response = request.execute()

        next_pg_token = response.get('nextPageToken')
        next_pg = True

        while next_pg_token != None:
            request = youtube.playlists().list(
                            part='snippet, contentDetails',
                            channelId=channel_id,
                            maxResults = 50,
                            pageToken = next_pg_token)
            response = request.execute()

            next_pg_token = response.get('nextPageToken')

        playlistResponse.append(response)
                
    titles = []
    ids = []
    channel_ids = []
    for channel in range(len(playlistResponse)):
        for i in range(len(playlistResponse[channel]['items'])):
                channelTitle = playlistResponse[channel]['items'][i]['snippet']['channelTitle']
                titles.append(playlistResponse[channel]['items'][i]['snippet']['title'])
                ids.append(playlistResponse[channel]['items'][i]['id'])
                channel_ids.append(playlistResponse[channel]['items'][i]['snippet']['channelId'])

    
    return titles, ids, channel_ids

# %%
titles,playlist_ids,channel_ids = getPlaylists(youtube, channel_ids)

# %%
zip_channels = zip(playlist_ids, channel_ids)

# %%
zip_playlist = zip(playlist_ids, titles)

# %% [markdown]
# ### Retrieving video ids using playlist ids

# %%
def get_vid_ids(playlist_ids):
    vidResponse = []
    
    for playlist_id in playlist_ids:
        request = youtube.playlistItems().list(
            part='contentDetails,snippet',
            playlistId=playlist_id,
            maxResults=50
        )

        response = request.execute()

        next_pg_token = response.get('nextPageToken')
        while next_pg_token:
            request = youtube.playlistItems().list(
                part='contentDetails,snippet',
                playlistId=playlist_id,
                maxResults=50,
                pageToken=next_pg_token
            )
            next_response = request.execute()
            response['items'].extend(next_response['items'])
            next_pg_token = next_response.get('nextPageToken')

        vidResponse.append(response)
        
        vid_ids = []
        play_id = []
        d = {}
        for i in range(len(vidResponse)):
            for j in range(len(vidResponse[i]['items'])):
                vid_ids.append(vidResponse[i]['items'][j]['contentDetails']['videoId'])
                play_id.append(vidResponse[i]['items'][j]['snippet']['playlistId'])
        
    return vid_ids, play_id

# %%
vid_ids, play_ids = get_vid_ids(playlist_ids)

# %%
zip_video = zip(vid_ids, play_ids)

# %% [markdown]
# ### Retrieving video details using video ideas

# %%
def get_vid_details(vid_id):
    vidDetResponse = []
    all_data = []
    
    for vid_id in vid_ids:
        request = youtube.videos().list(
            part = 'snippet,statistics,contentDetails',
            id = vid_id
            )
        response = request.execute()

        next_pg_token = response.get('nextPageToken')
        while next_pg_token:
            request = youtube.playlistItems().list(
                part='contentDetails,snippet,statistics',
                id=vid_id,
                maxResults=50,
                pageToken=next_pg_token
            )
            next_response = request.execute()
#             response['items'].extend(next_response['items'])
            next_pg_token = next_response.get('nextPageToken')

        vidDetResponse.append(response)
        
#     return vidDetResponse
    for i in range(len(vidDetResponse)):
        for j in range(len(vidDetResponse[i]['items'])):
            data = dict([
            ('vid_name', vidDetResponse[i]['items'][j]['snippet']['title']),
            ('channel_name', vidDetResponse[i]['items'][j]['snippet']['channelTitle']),
            ('publishedAt ', vidDetResponse[i]['items'][j]['snippet']['publishedAt']),
            ('views', vidDetResponse[i]['items'][j]['statistics']['viewCount']),
            ('likes', vidDetResponse[i]['items'][j]['statistics'].get('likeCount')),
            ('commentCount', vidDetResponse[i]['items'][j]['statistics'].get('commentCount')),
            ('vidID', vid_ids[i])
            ])
        all_data.append(data)
    return all_data

# %%
result = get_vid_details(vid_ids)

# %%
# result

# %%
# Creating Dataframe of video details
df = pd.DataFrame(result)

# %%
df
# Out:
#                                               vid_name          channel_name
# 0    J Balvin & Ed Sheeran - Forever My Love [Offic...            Ed Sheeran  \
# 1       J Balvin & Ed Sheeran - Sigue [Official Video]           jbalvinVEVO
# 2           J Balvin, Ed Sheeran - Sigue (Lyric Video)           jbalvinVEVO
# 3    J Balvin, Ed Sheeran - Forever My Love (Lyric ...           jbalvinVEVO
# 4    J Balvin, Willy William - Mi Gente (Official V...           jbalvinVEVO
# ..                                                 ...                   ...
# 887  "Memories In Disorder" | OFFICIAL 'MITO' DOCUM...  Dream Perfect Regime
# 888  DPR IAN - No Blueberries (ft. DPR LIVE, CL) OF...  Dream Perfect Regime
# 889              DPR IAN - So Beautiful (OFFICIAL M/V)  Dream Perfect Regime
# 890                                    Adobe x DPR IAN  Dream Perfect Regime
# 891                 our last dream - take 1 (Mongolia)  Dream Perfect Regime
#
#              publishedAt        views     likes commentCount        vidID
# 0    2022-03-25T00:00:12Z    18214532    451392        14376  bqtMJ391poA
# 1    2022-03-25T00:00:08Z    28013348    459494        18218  8pIzxS_G8-g
# 2    2022-05-31T16:00:02Z      530660     13149          270  3dCARL28qKs
# 3    2022-05-31T16:00:25Z      592553     15797          449  nKYFMqmV_Hg
# 4    2017-06-30T04:00:05Z  3239823387  17743131       523180  wnJ6LuUFpMo
# ..                    ...         ...       ...          ...          ...
# 887  2021-03-01T12:00:15Z      400633     48844         1764  GxdpLrtDsbg
# 888  2020-12-18T03:00:11Z    13975413    473491         9278  E-8pyVBvCPQ
# 889  2020-10-26T03:00:11Z    14411272    525228        15909  7QQzDQceGgU
# 890  2020-05-14T09:00:14Z      776766     74050         2663  gvLZhbq8SlY
# 891  2018-07-26T15:33:18Z      419918     36050         1626  0TBdBiW2ozc
#
# [892 rows x 7 columns]

# %% [markdown]
# #### Mapping column values

# %%
zip_video = list(zip_video)
dict_zip_video = dict(zip_video)
# Dictionary mapping vid_ids to corresponding values
vid_id_mapping = dict_zip_video
# Adding a new column based on vid_ids
df['Playlist_id'] = df['vidID'].map(vid_id_mapping)

# %%
zip_playlist = list(zip_playlist)
dict_zip_playlist = dict(zip_playlist)
playlist_name_mapping = dict_zip_playlist
df['Playlist_name'] = df['Playlist_id'].map(playlist_name_mapping)

# %%
zip_channels = list(zip_channels)
dict_zip_channels = dict(zip_channels)
channel_id_mapping = dict_zip_channels
df['channel_id'] = df['Playlist_id'].map(channel_id_mapping)
df
# Out:
#                                               vid_name          channel_name
# 0    J Balvin & Ed Sheeran - Forever My Love [Offic...            Ed Sheeran  \
# 1       J Balvin & Ed Sheeran - Sigue [Official Video]           jbalvinVEVO
# 2           J Balvin, Ed Sheeran - Sigue (Lyric Video)           jbalvinVEVO
# 3    J Balvin, Ed Sheeran - Forever My Love (Lyric ...           jbalvinVEVO
# 4    J Balvin, Willy William - Mi Gente (Official V...           jbalvinVEVO
# ..                                                 ...                   ...
# 887  "Memories In Disorder" | OFFICIAL 'MITO' DOCUM...  Dream Perfect Regime
# 888  DPR IAN - No Blueberries (ft. DPR LIVE, CL) OF...  Dream Perfect Regime
# 889              DPR IAN - So Beautiful (OFFICIAL M/V)  Dream Perfect Regime
# 890                                    Adobe x DPR IAN  Dream Perfect Regime
# 891                 our last dream - take 1 (Mongolia)  Dream Perfect Regime
#
#              publishedAt        views     likes commentCount        vidID
# 0    2022-03-25T00:00:12Z    18214532    451392        14376  bqtMJ391poA  \
# 1    2022-03-25T00:00:08Z    28013348    459494        18218  8pIzxS_G8-g
# 2    2022-05-31T16:00:02Z      530660     13149          270  3dCARL28qKs
# 3    2022-05-31T16:00:25Z      592553     15797          449  nKYFMqmV_Hg
# 4    2017-06-30T04:00:05Z  3239823387  17743131       523180  wnJ6LuUFpMo
# ..                    ...         ...       ...          ...          ...
# 887  2021-03-01T12:00:15Z      400633     48844         1764  GxdpLrtDsbg
# 888  2020-12-18T03:00:11Z    13975413    473491         9278  E-8pyVBvCPQ
# 889  2020-10-26T03:00:11Z    14411272    525228        15909  7QQzDQceGgU
# 890  2020-05-14T09:00:14Z      776766     74050         2663  gvLZhbq8SlY
# 891  2018-07-26T15:33:18Z      419918     36050         1626  0TBdBiW2ozc
#
#                             Playlist_id
# 0    PLWgVwtnp9KujNWv3gI631ccra2Pr44ccH  \
# 1    PLWgVwtnp9KujNWv3gI631ccra2Pr44ccH
# 2    PLWgVwtnp9KuifdEI3hEo0feBlmBjcUyJw
# 3    PLWgVwtnp9KuifdEI3hEo0feBlmBjcUyJw
# 4    PLWgVwtnp9KugbCR6Iw8f26137Udli6Jtq
# ..                                  ...
# 887  PLrnNYjIlGP9XoDpYQgTNTe4AnRbp3UIid
# 888  PLrnNYjIlGP9XoDpYQgTNTe4AnRbp3UIid
# 889  PLrnNYjIlGP9XoDpYQgTNTe4AnRbp3UIid
# 890  PLrnNYjIlGP9XoDpYQgTNTe4AnRbp3UIid
# 891  PLrnNYjIlGP9XoDpYQgTNTe4AnRbp3UIid
#
#                                       Playlist_name                channel_id
# 0                                   J Balvin x Hits  UCt-k6JwNWHMXDBGm9IYHdsg
# 1                                   J Balvin x Hits  UCt-k6JwNWHMXDBGm9IYHdsg
# 2    Sigue + Forever My Love - J Balvin, Ed Sheeran  UCt-k6JwNWHMXDBGm9IYHdsg
# 3    Sigue + Forever My Love - J Balvin, Ed Sheeran  UCt-k6JwNWHMXDBGm9IYHdsg
# 4                                      Music Videos  UCt-k6JwNWHMXDBGm9IYHdsg
# ..                                              ...                       ...
# 887                                         DPR IAN  UCtG5oKSlksz-QmD_2uI4WBw
# 888                                         DPR IAN  UCtG5oKSlksz-QmD_2uI4WBw
# 889                                         DPR IAN  UCtG5oKSlksz-QmD_2uI4WBw
# 890                                         DPR IAN  UCtG5oKSlksz-QmD_2uI4WBw
# 891                                         DPR IAN  UCtG5oKSlksz-QmD_2uI4WBw
#
# [892 rows x 10 columns]

# %% [markdown]
# ### Getting Subscriber count using channel ids

# %%
def get_subscriber_count(channel_id):
    response = youtube.channels().list(
        part='statistics, snippet',
        id=channel_id
    ).execute()

    subscriber_count = response['items'][0]['statistics']['subscriberCount']
    channel_name = response['items'][0]['snippet']['title']
    return int(subscriber_count), channel_name

# %%
channel_ids = [
               'UCt-k6JwNWHMXDBGm9IYHdsg',#JBalvin  
               'UC0WP5P-ufpRfjbNrmOWwLBQ',#Weeknd
               'UCPNxhDvTcytIdvwXWAm43cA',#selena
               'UCzpl23pGTHVYqvKsgY0A-_w',#doja
               'UCgJMQU7JOIoP-YnrhH_P-bA',#WDW 
               'UCtG5oKSlksz-QmD_2uI4WBw',#DPR
              ]
subs = []
artist_name = []
for channel_id in channel_ids:
    subs.append(get_subscriber_count(channel_id)[0])
    artist_name.append(get_subscriber_count(channel_id)[1])

# %%
zip_subs = zip(channel_ids, subs)
dict_zip_sub = dict(list(zip_subs))
df['subs'] = df['channel_id'].map(dict_zip_sub)
df
# Out:
#                                               vid_name          channel_name
# 0    J Balvin & Ed Sheeran - Forever My Love [Offic...            Ed Sheeran  \
# 1       J Balvin & Ed Sheeran - Sigue [Official Video]           jbalvinVEVO
# 2           J Balvin, Ed Sheeran - Sigue (Lyric Video)           jbalvinVEVO
# 3    J Balvin, Ed Sheeran - Forever My Love (Lyric ...           jbalvinVEVO
# 4    J Balvin, Willy William - Mi Gente (Official V...           jbalvinVEVO
# ..                                                 ...                   ...
# 887  "Memories In Disorder" | OFFICIAL 'MITO' DOCUM...  Dream Perfect Regime
# 888  DPR IAN - No Blueberries (ft. DPR LIVE, CL) OF...  Dream Perfect Regime
# 889              DPR IAN - So Beautiful (OFFICIAL M/V)  Dream Perfect Regime
# 890                                    Adobe x DPR IAN  Dream Perfect Regime
# 891                 our last dream - take 1 (Mongolia)  Dream Perfect Regime
#
#              publishedAt        views     likes commentCount        vidID
# 0    2022-03-25T00:00:12Z    18214532    451392        14376  bqtMJ391poA  \
# 1    2022-03-25T00:00:08Z    28013348    459494        18218  8pIzxS_G8-g
# 2    2022-05-31T16:00:02Z      530660     13149          270  3dCARL28qKs
# 3    2022-05-31T16:00:25Z      592553     15797          449  nKYFMqmV_Hg
# 4    2017-06-30T04:00:05Z  3239823387  17743131       523180  wnJ6LuUFpMo
# ..                    ...         ...       ...          ...          ...
# 887  2021-03-01T12:00:15Z      400633     48844         1764  GxdpLrtDsbg
# 888  2020-12-18T03:00:11Z    13975413    473491         9278  E-8pyVBvCPQ
# 889  2020-10-26T03:00:11Z    14411272    525228        15909  7QQzDQceGgU
# 890  2020-05-14T09:00:14Z      776766     74050         2663  gvLZhbq8SlY
# 891  2018-07-26T15:33:18Z      419918     36050         1626  0TBdBiW2ozc
#
#                             Playlist_id
# 0    PLWgVwtnp9KujNWv3gI631ccra2Pr44ccH  \
# 1    PLWgVwtnp9KujNWv3gI631ccra2Pr44ccH
# 2    PLWgVwtnp9KuifdEI3hEo0feBlmBjcUyJw
# 3    PLWgVwtnp9KuifdEI3hEo0feBlmBjcUyJw
# 4    PLWgVwtnp9KugbCR6Iw8f26137Udli6Jtq
# ..                                  ...
# 887  PLrnNYjIlGP9XoDpYQgTNTe4AnRbp3UIid
# 888  PLrnNYjIlGP9XoDpYQgTNTe4AnRbp3UIid
# 889  PLrnNYjIlGP9XoDpYQgTNTe4AnRbp3UIid
# 890  PLrnNYjIlGP9XoDpYQgTNTe4AnRbp3UIid
# 891  PLrnNYjIlGP9XoDpYQgTNTe4AnRbp3UIid
#
#                                       Playlist_name                channel_id
# 0                                   J Balvin x Hits  UCt-k6JwNWHMXDBGm9IYHdsg  \
# 1                                   J Balvin x Hits  UCt-k6JwNWHMXDBGm9IYHdsg
# 2    Sigue + Forever My Love - J Balvin, Ed Sheeran  UCt-k6JwNWHMXDBGm9IYHdsg
# 3    Sigue + Forever My Love - J Balvin, Ed Sheeran  UCt-k6JwNWHMXDBGm9IYHdsg
# 4                                      Music Videos  UCt-k6JwNWHMXDBGm9IYHdsg
# ..                                              ...                       ...
# 887                                         DPR IAN  UCtG5oKSlksz-QmD_2uI4WBw
# 888                                         DPR IAN  UCtG5oKSlksz-QmD_2uI4WBw
# 889                                         DPR IAN  UCtG5oKSlksz-QmD_2uI4WBw
# 890                                         DPR IAN  UCtG5oKSlksz-QmD_2uI4WBw
# 891                                         DPR IAN  UCtG5oKSlksz-QmD_2uI4WBw
#
#          subs
# 0    34000000
# 1    34000000
# 2    34000000
# 3    34000000
# 4    34000000
# ..        ...
# 887   1180000
# 888   1180000
# 889   1180000
# 890   1180000
# 891   1180000
#
# [892 rows x 11 columns]

# %%
zip_artists = zip(channel_ids, artist_name)
dict_zip_artists = dict(list(zip_artists))
df['artist'] = df['channel_id'].map(dict_zip_artists)
df
# Out:
#                                               vid_name          channel_name
# 0    J Balvin & Ed Sheeran - Forever My Love [Offic...            Ed Sheeran  \
# 1       J Balvin & Ed Sheeran - Sigue [Official Video]           jbalvinVEVO
# 2           J Balvin, Ed Sheeran - Sigue (Lyric Video)           jbalvinVEVO
# 3    J Balvin, Ed Sheeran - Forever My Love (Lyric ...           jbalvinVEVO
# 4    J Balvin, Willy William - Mi Gente (Official V...           jbalvinVEVO
# ..                                                 ...                   ...
# 887  "Memories In Disorder" | OFFICIAL 'MITO' DOCUM...  Dream Perfect Regime
# 888  DPR IAN - No Blueberries (ft. DPR LIVE, CL) OF...  Dream Perfect Regime
# 889              DPR IAN - So Beautiful (OFFICIAL M/V)  Dream Perfect Regime
# 890                                    Adobe x DPR IAN  Dream Perfect Regime
# 891                 our last dream - take 1 (Mongolia)  Dream Perfect Regime
#
#              publishedAt        views     likes commentCount        vidID
# 0    2022-03-25T00:00:12Z    18214532    451392        14376  bqtMJ391poA  \
# 1    2022-03-25T00:00:08Z    28013348    459494        18218  8pIzxS_G8-g
# 2    2022-05-31T16:00:02Z      530660     13149          270  3dCARL28qKs
# 3    2022-05-31T16:00:25Z      592553     15797          449  nKYFMqmV_Hg
# 4    2017-06-30T04:00:05Z  3239823387  17743131       523180  wnJ6LuUFpMo
# ..                    ...         ...       ...          ...          ...
# 887  2021-03-01T12:00:15Z      400633     48844         1764  GxdpLrtDsbg
# 888  2020-12-18T03:00:11Z    13975413    473491         9278  E-8pyVBvCPQ
# 889  2020-10-26T03:00:11Z    14411272    525228        15909  7QQzDQceGgU
# 890  2020-05-14T09:00:14Z      776766     74050         2663  gvLZhbq8SlY
# 891  2018-07-26T15:33:18Z      419918     36050         1626  0TBdBiW2ozc
#
#                             Playlist_id
# 0    PLWgVwtnp9KujNWv3gI631ccra2Pr44ccH  \
# 1    PLWgVwtnp9KujNWv3gI631ccra2Pr44ccH
# 2    PLWgVwtnp9KuifdEI3hEo0feBlmBjcUyJw
# 3    PLWgVwtnp9KuifdEI3hEo0feBlmBjcUyJw
# 4    PLWgVwtnp9KugbCR6Iw8f26137Udli6Jtq
# ..                                  ...
# 887  PLrnNYjIlGP9XoDpYQgTNTe4AnRbp3UIid
# 888  PLrnNYjIlGP9XoDpYQgTNTe4AnRbp3UIid
# 889  PLrnNYjIlGP9XoDpYQgTNTe4AnRbp3UIid
# 890  PLrnNYjIlGP9XoDpYQgTNTe4AnRbp3UIid
# 891  PLrnNYjIlGP9XoDpYQgTNTe4AnRbp3UIid
#
#                                       Playlist_name                channel_id
# 0                                   J Balvin x Hits  UCt-k6JwNWHMXDBGm9IYHdsg  \
# 1                                   J Balvin x Hits  UCt-k6JwNWHMXDBGm9IYHdsg
# 2    Sigue + Forever My Love - J Balvin, Ed Sheeran  UCt-k6JwNWHMXDBGm9IYHdsg
# 3    Sigue + Forever My Love - J Balvin, Ed Sheeran  UCt-k6JwNWHMXDBGm9IYHdsg
# 4                                      Music Videos  UCt-k6JwNWHMXDBGm9IYHdsg
# ..                                              ...                       ...
# 887                                         DPR IAN  UCtG5oKSlksz-QmD_2uI4WBw
# 888                                         DPR IAN  UCtG5oKSlksz-QmD_2uI4WBw
# 889                                         DPR IAN  UCtG5oKSlksz-QmD_2uI4WBw
# 890                                         DPR IAN  UCtG5oKSlksz-QmD_2uI4WBw
# 891                                         DPR IAN  UCtG5oKSlksz-QmD_2uI4WBw
#
#          subs                artist
# 0    34000000              J Balvin
# 1    34000000              J Balvin
# 2    34000000              J Balvin
# 3    34000000              J Balvin
# 4    34000000              J Balvin
# ..        ...                   ...
# 887   1180000  Dream Perfect Regime
# 888   1180000  Dream Perfect Regime
# 889   1180000  Dream Perfect Regime
# 890   1180000  Dream Perfect Regime
# 891   1180000  Dream Perfect Regime
#
# [892 rows x 12 columns]

# %%
df.to_csv('songsVidDetails.csv')

# %%
df1 = df.groupby('Playlist_name').count()

# %%
df1.shape
# Out:
# (62, 11)

# %%
pd.set_option('display.max_rows', 62)
df1
# Out:
#                                                     vid_name  channel_name
# Playlist_name
# #JOSE x TikTok LIVE                                       17            17  \
# 927 Club                                                   2             2
# Acapella Videos                                            6             6
# Aprende Los Colores con J Balvin                          10            10
# Collaborations                                            23            23
# Colores                                                    3             3
# Colores Singalong Videos                                  10            10
# DPR CREAM                                                  1             1
# DPR IAN                                                   16            16
# DPR LIVE                                                  24            24
# Dawn FM (Lyric Videos)                                    13            13
# Dawn FM Experience                                         6             6
# Doja Apperances                                           18            18
# Doja Cat - Video Essentials                               21            21
# ENERGÍA ⚡ 5-YEAR-ANNIVERSARY                              11            11
# Favorites                                                 14            14
# In Da Getto                                                2             2
# J Balvin x Activo                                          1             1
# J Balvin x Fiesta                                          1             1
# J Balvin x Hits                                           42            42
# J Balvin x Pandora LIVE                                    5             5
# J Balvin x Romántico                                       3             3
# J Balvin x Suave                                           6             6
# J Balvin x Top 15                                          4             4
# JOSE                                                      22            22
# Live Performances                                          9             9
# Live on the Honda Stage at the Hammerstein Ball...         3             3
# Music Videos                                             181           181
# My Dear Melancholy,                                        6             6
# My Mind & Me                                               7             7
# Official Videos                                           50            50
# Out On Tour                                                1             1
# Selena Gomez - RARE                                       33            33
# Selena Gomez - REVELACIÓN                                 11            11
# Sigue + Forever My Love - J Balvin, Ed Sheeran             2             2
# TV Performances                                           13            13
# Tea Time with Why Don't We                                10            10
# The Good Times and The Bad Ones: Influences               11            11
# The Idol (Music from the HBO Original Series)             29            29
# The Weeknd - Echoes Of Silence (Mixtape)                   9             9
# The Weeknd - House Of Balloons (Mixtape)                   9             9
# The Weeknd - Thursday (Mixtape)                            9             9
# The Weeknd: Live at SoFi Stadium                           3             3
# VEVO - Live Performances                                   1             1
# VIDEOS                                                    10            10
# Vevo LIFT                                                  3             3
# Vevo Official Live Performances                            3             3
# Vevo Presents: The Weeknd @ Mod Club                       7             7
# WHY DON’T WE - COACHELLA 22                                1             1
# Watch Us on RELEASED                                       1             1
# Why Don't We - Don't Wake Me Up with Jonas Blue            2             2
# Why Don't We - Love Back                                   3             3
# Why Don't We - Vevo Live                                   2             2
# Why Don't We • Best Of                                     2             2
# Why Don't We • Fallin'                                    10            10
# Why Don't We • Interviews                                 54            54
# Why Don't We • Official Audio                             39            39
# Why Don't We • Official Music Videos                      45            45
# Why Don't We • The Good Times And The Bad Ones            12            12
# Why Don't We • Vlogs                                       7             7
# Why Don't We • What Am I                                   6             6
# XO LET’S GOOO 🔥                                            7             7
#
#                                                     publishedAt   views
# Playlist_name
# #JOSE x TikTok LIVE                                           17     17  \
# 927 Club                                                       2      2
# Acapella Videos                                                6      6
# Aprende Los Colores con J Balvin                              10     10
# Collaborations                                                23     23
# Colores                                                        3      3
# Colores Singalong Videos                                      10     10
# DPR CREAM                                                      1      1
# DPR IAN                                                       16     16
# DPR LIVE                                                      24     24
# Dawn FM (Lyric Videos)                                        13     13
# Dawn FM Experience                                             6      6
# Doja Apperances                                               18     18
# Doja Cat - Video Essentials                                   21     21
# ENERGÍA ⚡ 5-YEAR-ANNIVERSARY                                  11     11
# Favorites                                                     14     14
# In Da Getto                                                    2      2
# J Balvin x Activo                                              1      1
# J Balvin x Fiesta                                              1      1
# J Balvin x Hits                                               42     42
# J Balvin x Pandora LIVE                                        5      5
# J Balvin x Romántico                                           3      3
# J Balvin x Suave                                               6      6
# J Balvin x Top 15                                              4      4
# JOSE                                                          22     22
# Live Performances                                              9      9
# Live on the Honda Stage at the Hammerstein Ball...             3      3
# Music Videos                                                 181    181
# My Dear Melancholy,                                            6      6
# My Mind & Me                                                   7      7
# Official Videos                                               50     50
# Out On Tour                                                    1      1
# Selena Gomez - RARE                                           33     33
# Selena Gomez - REVELACIÓN                                     11     11
# Sigue + Forever My Love - J Balvin, Ed Sheeran                 2      2
# TV Performances                                               13     13
# Tea Time with Why Don't We                                    10     10
# The Good Times and The Bad Ones: Influences                   11     11
# The Idol (Music from the HBO Original Series)                 29     29
# The Weeknd - Echoes Of Silence (Mixtape)                       9      9
# The Weeknd - House Of Balloons (Mixtape)                       9      9
# The Weeknd - Thursday (Mixtape)                                9      9
# The Weeknd: Live at SoFi Stadium                               3      3
# VEVO - Live Performances                                       1      1
# VIDEOS                                                        10     10
# Vevo LIFT                                                      3      3
# Vevo Official Live Performances                                3      3
# Vevo Presents: The Weeknd @ Mod Club                           7      7
# WHY DON’T WE - COACHELLA 22                                    1      1
# Watch Us on RELEASED                                           1      1
# Why Don't We - Don't Wake Me Up with Jonas Blue                2      2
# Why Don't We - Love Back                                       3      3
# Why Don't We - Vevo Live                                       2      2
# Why Don't We • Best Of                                         2      2
# Why Don't We • Fallin'                                        10     10
# Why Don't We • Interviews                                     54     54
# Why Don't We • Official Audio                                 39     39
# Why Don't We • Official Music Videos                          45     45
# Why Don't We • The Good Times And The Bad Ones                12     12
# Why Don't We • Vlogs                                           7      7
# Why Don't We • What Am I                                       6      6
# XO LET’S GOOO 🔥                                                7      7
#
#                                                     likes  commentCount
# Playlist_name
# #JOSE x TikTok LIVE                                    17            17  \
# 927 Club                                                2             2
# Acapella Videos                                         6             6
# Aprende Los Colores con J Balvin                       10            10
# Collaborations                                         23            23
# Colores                                                 3             3
# Colores Singalong Videos                               10            10
# DPR CREAM                                               1             1
# DPR IAN                                                16            16
# DPR LIVE                                               24            24
# Dawn FM (Lyric Videos)                                 13            13
# Dawn FM Experience                                      6             6
# Doja Apperances                                        18            18
# Doja Cat - Video Essentials                            21            21
# ENERGÍA ⚡ 5-YEAR-ANNIVERSARY                           11            11
# Favorites                                              14            14
# In Da Getto                                             2             2
# J Balvin x Activo                                       1             1
# J Balvin x Fiesta                                       1             1
# J Balvin x Hits                                        42            42
# J Balvin x Pandora LIVE                                 5             5
# J Balvin x Romántico                                    3             3
# J Balvin x Suave                                        6             6
# J Balvin x Top 15                                       4             4
# JOSE                                                   22            22
# Live Performances                                       9             9
# Live on the Honda Stage at the Hammerstein Ball...      3             3
# Music Videos                                          181           181
# My Dear Melancholy,                                     6             6
# My Mind & Me                                            7             6
# Official Videos                                        50            50
# Out On Tour                                             1             1
# Selena Gomez - RARE                                    33            33
# Selena Gomez - REVELACIÓN                              11            11
# Sigue + Forever My Love - J Balvin, Ed Sheeran          2             2
# TV Performances                                        13            13
# Tea Time with Why Don't We                             10            10
# The Good Times and The Bad Ones: Influences            11            11
# The Idol (Music from the HBO Original Series)          29            29
# The Weeknd - Echoes Of Silence (Mixtape)                9             9
# The Weeknd - House Of Balloons (Mixtape)                9             9
# The Weeknd - Thursday (Mixtape)                         9             9
# The Weeknd: Live at SoFi Stadium                        3             3
# VEVO - Live Performances                                1             1
# VIDEOS                                                 10            10
# Vevo LIFT                                               3             3
# Vevo Official Live Performances                         3             3
# Vevo Presents: The Weeknd @ Mod Club                    7             7
# WHY DON’T WE - COACHELLA 22                             1             1
# Watch Us on RELEASED                                    1             1
# Why Don't We - Don't Wake Me Up with Jonas Blue         2             2
# Why Don't We - Love Back                                3             3
# Why Don't We - Vevo Live                                2             2
# Why Don't We • Best Of                                  2             2
# Why Don't We • Fallin'                                 10            10
# Why Don't We • Interviews                              53            52
# Why Don't We • Official Audio                          39            39
# Why Don't We • Official Music Videos                   45            45
# Why Don't We • The Good Times And The Bad Ones         12            12
# Why Don't We • Vlogs                                    7             7
# Why Don't We • What Am I                                6             6
# XO LET’S GOOO 🔥                                         7             7
#
#                                                     vidID  Playlist_id
# Playlist_name
# #JOSE x TikTok LIVE                                    17           17  \
# 927 Club                                                2            2
# Acapella Videos                                         6            6
# Aprende Los Colores con J Balvin                       10           10
# Collaborations                                         23           23
# Colores                                                 3            3
# Colores Singalong Videos                               10           10
# DPR CREAM                                               1            1
# DPR IAN                                                16           16
# DPR LIVE                                               24           24
# Dawn FM (Lyric Videos)                                 13           13
# Dawn FM Experience                                      6            6
# Doja Apperances                                        18           18
# Doja Cat - Video Essentials                            21           21
# ENERGÍA ⚡ 5-YEAR-ANNIVERSARY                           11           11
# Favorites                                              14           14
# In Da Getto                                             2            2
# J Balvin x Activo                                       1            1
# J Balvin x Fiesta                                       1            1
# J Balvin x Hits                                        42           42
# J Balvin x Pandora LIVE                                 5            5
# J Balvin x Romántico                                    3            3
# J Balvin x Suave                                        6            6
# J Balvin x Top 15                                       4            4
# JOSE                                                   22           22
# Live Performances                                       9            9
# Live on the Honda Stage at the Hammerstein Ball...      3            3
# Music Videos                                          181          181
# My Dear Melancholy,                                     6            6
# My Mind & Me                                            7            7
# Official Videos                                        50           50
# Out On Tour                                             1            1
# Selena Gomez - RARE                                    33           33
# Selena Gomez - REVELACIÓN                              11           11
# Sigue + Forever My Love - J Balvin, Ed Sheeran          2            2
# TV Performances                                        13           13
# Tea Time with Why Don't We                             10           10
# The Good Times and The Bad Ones: Influences            11           11
# The Idol (Music from the HBO Original Series)          29           29
# The Weeknd - Echoes Of Silence (Mixtape)                9            9
# The Weeknd - House Of Balloons (Mixtape)                9            9
# The Weeknd - Thursday (Mixtape)                         9            9
# The Weeknd: Live at SoFi Stadium                        3            3
# VEVO - Live Performances                                1            1
# VIDEOS                                                 10           10
# Vevo LIFT                                               3            3
# Vevo Official Live Performances                         3            3
# Vevo Presents: The Weeknd @ Mod Club                    7            7
# WHY DON’T WE - COACHELLA 22                             1            1
# Watch Us on RELEASED                                    1            1
# Why Don't We - Don't Wake Me Up with Jonas Blue         2            2
# Why Don't We - Love Back                                3            3
# Why Don't We - Vevo Live                                2            2
# Why Don't We • Best Of                                  2            2
# Why Don't We • Fallin'                                 10           10
# Why Don't We • Interviews                              54           54
# Why Don't We • Official Audio                          39           39
# Why Don't We • Official Music Videos                   45           45
# Why Don't We • The Good Times And The Bad Ones         12           12
# Why Don't We • Vlogs                                    7            7
# Why Don't We • What Am I                                6            6
# XO LET’S GOOO 🔥                                         7            7
#
#                                                     channel_id  subs  artist
# Playlist_name
# #JOSE x TikTok LIVE                                         17    17      17
# 927 Club                                                     2     2       2
# Acapella Videos                                              6     6       6
# Aprende Los Colores con J Balvin                            10    10      10
# Collaborations                                              23    23      23
# Colores                                                      3     3       3
# Colores Singalong Videos                                    10    10      10
# DPR CREAM                                                    1     1       1
# DPR IAN                                                     16    16      16
# DPR LIVE                                                    24    24      24
# Dawn FM (Lyric Videos)                                      13    13      13
# Dawn FM Experience                                           6     6       6
# Doja Apperances                                             18    18      18
# Doja Cat - Video Essentials                                 21    21      21
# ENERGÍA ⚡ 5-YEAR-ANNIVERSARY                                11    11      11
# Favorites                                                   14    14      14
# In Da Getto                                                  2     2       2
# J Balvin x Activo                                            1     1       1
# J Balvin x Fiesta                                            1     1       1
# J Balvin x Hits                                             42    42      42
# J Balvin x Pandora LIVE                                      5     5       5
# J Balvin x Romántico                                         3     3       3
# J Balvin x Suave                                             6     6       6
# J Balvin x Top 15                                            4     4       4
# JOSE                                                        22    22      22
# Live Performances                                            9     9       9
# Live on the Honda Stage at the Hammerstein Ball...           3     3       3
# Music Videos                                               181   181     181
# My Dear Melancholy,                                          6     6       6
# My Mind & Me                                                 7     7       7
# Official Videos                                             50    50      50
# Out On Tour                                                  1     1       1
# Selena Gomez - RARE                                         33    33      33
# Selena Gomez - REVELACIÓN                                   11    11      11
# Sigue + Forever My Love - J Balvin, Ed Sheeran               2     2       2
# TV Performances                                             13    13      13
# Tea Time with Why Don't We                                  10    10      10
# The Good Times and The Bad Ones: Influences                 11    11      11
# The Idol (Music from the HBO Original Series)               29    29      29
# The Weeknd - Echoes Of Silence (Mixtape)                     9     9       9
# The Weeknd - House Of Balloons (Mixtape)                     9     9       9
# The Weeknd - Thursday (Mixtape)                              9     9       9
# The Weeknd: Live at SoFi Stadium                             3     3       3
# VEVO - Live Performances                                     1     1       1
# VIDEOS                                                      10    10      10
# Vevo LIFT                                                    3     3       3
# Vevo Official Live Performances                              3     3       3
# Vevo Presents: The Weeknd @ Mod Club                         7     7       7
# WHY DON’T WE - COACHELLA 22                                  1     1       1
# Watch Us on RELEASED                                         1     1       1
# Why Don't We - Don't Wake Me Up with Jonas Blue              2     2       2
# Why Don't We - Love Back                                     3     3       3
# Why Don't We - Vevo Live                                     2     2       2
# Why Don't We • Best Of                                       2     2       2
# Why Don't We • Fallin'                                      10    10      10
# Why Don't We • Interviews                                   54    54      54
# Why Don't We • Official Audio                               39    39      39
# Why Don't We • Official Music Videos                        45    45      45
# Why Don't We • The Good Times And The Bad Ones              12    12      12
# Why Don't We • Vlogs                                         7     7       7
# Why Don't We • What Am I                                     6     6       6
# XO LET’S GOOO 🔥                                              7     7       7
